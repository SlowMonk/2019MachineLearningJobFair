# %% [markdown]
# # Overview
# We try here to improve another public U-Net model: https://www.kaggle.com/kmader/baseline-u-net-model-part-1 which shows how to extract the segmentation map for the ships, augment the images and train a simple DNN model to detect them. A few additional tweaks like balancing the ship-count out a little better have also been done.
#
# We are using a different loss function (closer to the competition scoring) and also fix and improve some visualisation functions and the submission itself.

# %% [markdown]
# ## Model Parameters
# We might want to adjust these later (or do some hyperparameter optimizations)

# %%
import keras
import tensorflow as tf
print(keras.__version__)
print(tf.__version__)
# Out:
# Using TensorFlow backend.
# 2.3.1
# 2.0.0

# %%
#from keras import backend as K
#K.tensorflow_backend._get_available_gpus()

# %%
#config = tf.ConfigProto(device_count = {'GPU': 1})

# %%
#tf.config.list_physical_devices(
#    device_type=None
#)
#physical_devices = tf.config.list_physical_devices('GPU') 
#print("Num GPUs:", len(physical_devices))

# %%
BATCH_SIZE = 48
EDGE_CROP = 16
GAUSSIAN_NOISE = 0.1
UPSAMPLE_MODE = 'SIMPLE'
# downsampling inside the network
NET_SCALING = (1, 1)
# downsampling in preprocessing
IMG_SCALING = (3, 3)
# number of validation images to use
VALID_IMG_COUNT = 900
# maximum number of steps_per_epoch in training
MAX_TRAIN_STEPS = 9
MAX_TRAIN_EPOCHS = 99
AUGMENT_BRIGHTNESS = False

# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from skimage.io import imread
import matplotlib.pyplot as plt
from skimage.segmentation import mark_boundaries
#from skimage.util.montage import montage2d as montage
path = "/mnt/3CE35B99003D727B/input/kaggle/Airbus Ship Detection Challenge/"
from keras import models, layers

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"] = "1"


masks = pd.read_csv(os.path.join(path + 'train_ship_segmentations_v2.csv'))

print(masks.shape[0],'masks found')

masks.head()
# Out:
# 231723 masks found
#          ImageId                                      EncodedPixels
# 0  00003e153.jpg                                                NaN
# 1  0001124c7.jpg                                                NaN
# 2  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 3  000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 4  000194a2d.jpg  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...

# %%
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from skimage.io import imread
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from skimage.segmentation import mark_boundaries
from skimage.util import montage2d as montage
from skimage.morphology import binary_opening, disk, label
import gc; gc.enable() # memory is tight

montage_rgb = lambda x: np.stack([montage(x[:, :, :, i]) for i in range(x.shape[3])], -1)
ship_dir = path
train_image_dir = os.path.join(ship_dir, 'train_v2')
test_image_dir = os.path.join(ship_dir, 'test_v2')

def multi_rle_encode(img, **kwargs):
    '''
    Encode connected regions as separated masks
    '''
    labels = label(img)
    if img.ndim > 2:
        return [rle_encode(np.sum(labels==k, axis=2), **kwargs) for k in np.unique(labels[labels>0])]
    else:
        return [rle_encode(labels==k, **kwargs) for k in np.unique(labels[labels>0])]

# ref: https://www.kaggle.com/paulorzp/run-length-encode-and-decode
def rle_encode(img, min_max_threshold=1e-3, max_mean_threshold=None):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    if np.max(img) < min_max_threshold:
        return '' ## no need to encode if it's all zeros
    if max_mean_threshold and np.mean(img) > max_mean_threshold:
        return '' ## ignore overfilled mask
    pixels = img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def rle_decode(mask_rle, shape=(768, 768)):
    '''
    mask_rle: run-length as string formated (start length)
    shape: (height,width) of array to return 
    Returns numpy array, 1 - mask, 0 - background
    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T  # Needed to align to RLE direction

def masks_as_image(in_mask_list):
    # Take the individual ship masks and create a single mask array for all ships
    all_masks = np.zeros((768, 768), dtype = np.uint8)
    for mask in in_mask_list:
        if isinstance(mask, str):
            all_masks |= rle_decode(mask)
    return all_masks

def masks_as_color(in_mask_list):
    # Take the individual ship masks and create a color mask array for each ships
    all_masks = np.zeros((768, 768), dtype = np.float)
    scale = lambda x: (len(in_mask_list)+x+1) / (len(in_mask_list)*2) ## scale the heatmap image to shift 
    for i,mask in enumerate(in_mask_list):
        if isinstance(mask, str):
            all_masks[:,:] += scale(i) * rle_decode(mask)
    return all_masks

# %%
import keras
print(keras.__version__)
# Out:
# 2.3.1

# %% [markdown]
# # Make sure encode/decode works
# Given the process
# $$  RLE_0 \stackrel{Decode}{\longrightarrow} \textrm{Image}_0 \stackrel{Encode}{\longrightarrow} RLE_1 \stackrel{Decode}{\longrightarrow} \textrm{Image}_1 $$
# We want to check if/that
# $ \textrm{Image}_0 \stackrel{?}{=} \textrm{Image}_1 $
# We could check the RLEs as well but that is more tedious. Also depending on how the objects have been labeled we might have different counts.

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (16, 5))
rle_0 = masks.query('ImageId=="00021ddc3.jpg"')['EncodedPixels']
img_0 = masks_as_image(rle_0)
ax1.imshow(img_0)
ax1.set_title('Mask as image')
rle_1 = multi_rle_encode(img_0)
img_1 = masks_as_image(rle_1)
ax2.imshow(img_1)
ax2.set_title('Re-encoded')
img_c = masks_as_color(rle_0)
ax3.imshow(img_c)
ax3.set_title('Masks in colors')
img_c = masks_as_color(rle_1)
ax4.imshow(img_c)
ax4.set_title('Re-encoded in colors')
print('Check Decoding->Encoding',
      'RLE_0:', len(rle_0), '->',
      'RLE_1:', len(rle_1))
print(np.sum(img_0 - img_1), 'error')
# Out:
# Check Decoding->Encoding RLE_0: 9 -> RLE_1: 4
# 0 error

# %% [markdown]
# # Split into training and validation groups
# We stratify by the number of boats appearing so we have nice balances in each set

# %%
masks['ships'] = masks['EncodedPixels'].map(lambda c_row: 1 if isinstance(c_row, str) else 0)
unique_img_ids = masks.groupby('ImageId').agg({'ships': 'sum'}).reset_index()
unique_img_ids['has_ship'] = unique_img_ids['ships'].map(lambda x: 1.0 if x>0 else 0.0)
unique_img_ids['has_ship_vec'] = unique_img_ids['has_ship'].map(lambda x: [x])
# some files are too small/corrupt
unique_img_ids['file_size_kb'] = unique_img_ids['ImageId'].map(lambda c_img_id: 
                                                               os.stat(os.path.join(train_image_dir, 
                                                                                    c_img_id)).st_size/1024)
unique_img_ids = unique_img_ids[unique_img_ids['file_size_kb'] > 50] # keep only +50kb files
unique_img_ids['file_size_kb'].hist()
masks.drop(['ships'], axis=1, inplace=True)
unique_img_ids.sample(7)
# Out:
#               ImageId  ships  has_ship has_ship_vec  file_size_kb
# 176768  eb1bd4a1f.jpg      1       1.0        [1.0]     98.407227
# 191334  fe65892fb.jpg      2       1.0        [1.0]    144.653320
# 30506   288344e0d.jpg      0       0.0        [0.0]     99.929688
# 7862    0a7c8e4a1.jpg      0       0.0        [0.0]    162.388672
# 184050  f4bac2f82.jpg      0       0.0        [0.0]    223.198242
# 90943   78c54cd15.jpg      0       0.0        [0.0]    111.419922
# 134015  b23156d3e.jpg      0       0.0        [0.0]    256.399414

# %% [markdown]
# ### Examine Number of Ship Images
# Here we examine how often ships appear and replace the ones without any ships with 0

# %%
unique_img_ids['ships'].hist(bins=unique_img_ids['ships'].max())

# %% [markdown]
# # Undersample Empty Images
# Here we undersample the empty images to get a better balanced group with more ships to try and segment

# %%
SAMPLES_PER_GROUP = 2000
balanced_train_df = unique_img_ids.groupby('ships').apply(lambda x: x.sample(SAMPLES_PER_GROUP) if len(x) > SAMPLES_PER_GROUP else x)
balanced_train_df['ships'].hist(bins=balanced_train_df['ships'].max()+1)
print(balanced_train_df.shape[0], 'masks')
# Out:
# 12788 masks

# %%
balanced_train_df
# Out:
#                     ImageId  ships  has_ship has_ship_vec  file_size_kb
# ships
# 0     210     0045fbd7c.jpg      0       0.0        [0.0]     99.791016
#       77765   675c1c871.jpg      0       0.0        [0.0]    213.375000
#       54515   48969232d.jpg      0       0.0        [0.0]    128.720703
#       6730    08ee1008d.jpg      0       0.0        [0.0]    100.801758
#       57708   4cef3e0e0.jpg      0       0.0        [0.0]     94.518555
# ...                     ...    ...       ...          ...           ...
# 15    176401  ea9f82665.jpg     15       1.0        [1.0]    128.476562
#       179547  eec04e7a8.jpg     15       1.0        [1.0]    146.968750
#       186407  f7e6819bb.jpg     15       1.0        [1.0]    113.709961
#       190392  fd1de824c.jpg     15       1.0        [1.0]    147.061523
#       192184  ff7ac7f3c.jpg     15       1.0        [1.0]    198.810547
#
# [12788 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
train_ids, valid_ids = train_test_split(balanced_train_df, 
                 test_size = 0.2, 
                 stratify = balanced_train_df['ships'])
train_df = pd.merge(masks, train_ids)
valid_df = pd.merge(masks, valid_ids)
print(train_df.shape[0], 'training masks')
print(valid_df.shape[0], 'validation masks')
# Out:
# 35364 training masks
# 8838 validation masks

# %% [markdown]
# # Decode all the RLEs into Images
# We make a generator to produce batches of images

# %%
def make_image_gen(in_df, batch_size = BATCH_SIZE):
    all_batches = list(in_df.groupby('ImageId'))
    out_rgb = []
    out_mask = []
    while True:
        np.random.shuffle(all_batches)
        for c_img_id, c_masks in all_batches:
            rgb_path = os.path.join(train_image_dir, c_img_id)
            c_img = imread(rgb_path)
            c_mask = np.expand_dims(masks_as_image(c_masks['EncodedPixels'].values), -1)
            if IMG_SCALING is not None:
                c_img = c_img[::IMG_SCALING[0], ::IMG_SCALING[1]]
                c_mask = c_mask[::IMG_SCALING[0], ::IMG_SCALING[1]]
            out_rgb += [c_img]
            out_mask += [c_mask]
            if len(out_rgb)>=batch_size:
                yield np.stack(out_rgb, 0)/255.0, np.stack(out_mask, 0)
                out_rgb, out_mask=[], []

# %%
train_gen = make_image_gen(train_df)
train_x, train_y = next(train_gen)
print('x', train_x.shape, train_x.min(), train_x.max())
print('y', train_y.shape, train_y.min(), train_y.max())
# Out:
# x (48, 256, 256, 3) 0.0 1.0
# y (48, 256, 256, 1) 0 1

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (30, 10))
batch_rgb = montage_rgb(train_x)
batch_seg = montage(train_y[:, :, :, 0])
ax1.imshow(batch_rgb)
ax1.set_title('Images')
ax2.imshow(batch_seg)
ax2.set_title('Segmentations')
ax3.imshow(mark_boundaries(batch_rgb, 
                           batch_seg.astype(int)))
ax3.set_title('Outlined Ships')
fig.savefig('overview.png')
# Out:
# /home/jake/venv/lib/python3.7/site-packages/skimage/util/_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# /home/jake/venv/lib/python3.7/site-packages/skimage/util/_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# /home/jake/venv/lib/python3.7/site-packages/skimage/util/_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# /home/jake/venv/lib/python3.7/site-packages/skimage/util/_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,

# %% [markdown]
# # Make the Validation Set

# %%
# %%time
valid_x, valid_y = next(make_image_gen(valid_df, VALID_IMG_COUNT))
print(valid_x.shape, valid_y.shape)
# Out:
# (900, 256, 256, 3) (900, 256, 256, 1)
# CPU times: user 13.3 s, sys: 994 ms, total: 14.3 s
# Wall time: 33.6 s

# %% [markdown]
# # Augment Data

# %%
from keras.preprocessing.image import ImageDataGenerator
dg_args = dict(featurewise_center = False, 
                  samplewise_center = False,
                  rotation_range = 45, 
                  width_shift_range = 0.1, 
                  height_shift_range = 0.1, 
                  shear_range = 0.01,
                  zoom_range = [0.9, 1.25],  
                  horizontal_flip = True, 
                  vertical_flip = True,
                  fill_mode = 'reflect')
# brightness can be problematic since it seems to change the labels differently from the images 
if AUGMENT_BRIGHTNESS:
    dg_args[' brightness_range'] = [0.5, 1.5]
image_gen = ImageDataGenerator(**dg_args)

if AUGMENT_BRIGHTNESS:
    dg_args.pop('brightness_range')
label_gen = ImageDataGenerator(**dg_args)

def create_aug_gen(in_gen, seed = None):
    np.random.seed(seed if seed is not None else np.random.choice(range(9999)))
    for in_x, in_y in in_gen:
        seed = np.random.choice(range(9999))
        # keep the seeds syncronized otherwise the augmentation to the images is different from the masks
        g_x = image_gen.flow(255*in_x, 
                             batch_size = in_x.shape[0], 
                             seed = seed, 
                             shuffle=True)
        g_y = label_gen.flow(in_y, 
                             batch_size = in_x.shape[0], 
                             seed = seed, 
                             shuffle=True)

        yield next(g_x)/255.0, next(g_y)

# %%
cur_gen = create_aug_gen(train_gen)
t_x, t_y = next(cur_gen)
print('x', t_x.shape, t_x.dtype, t_x.min(), t_x.max())
print('y', t_y.shape, t_y.dtype, t_y.min(), t_y.max())
# only keep first 9 samples to examine in detail
t_x = t_x[:9]
t_y = t_y[:9]
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 10))
ax1.imshow(montage_rgb(t_x), cmap='gray')
ax1.set_title('images')
ax2.imshow(montage(t_y[:, :, :, 0]), cmap='gray_r')
ax2.set_title('ships')
# Out:
# x (48, 256, 256, 3) float32 0.0 1.0
# y (48, 256, 256, 1) float32 0.0 1.0
# /home/jake/venv/lib/python3.7/site-packages/skimage/util/_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# /home/jake/venv/lib/python3.7/site-packages/skimage/util/_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# /home/jake/venv/lib/python3.7/site-packages/skimage/util/_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# /home/jake/venv/lib/python3.7/site-packages/skimage/util/_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# Text(0.5, 1.0, 'ships')

# %%
gc.collect()
# Out:
# 27

# %% [markdown]
# # Build a Model
# Here we use a slight deviation on the U-Net standard

# %%
from keras import models, layers
# Build U-Net model
def upsample_conv(filters, kernel_size, strides, padding):
    return layers.Conv2DTranspose(filters, kernel_size, strides=strides, padding=padding)
def upsample_simple(filters, kernel_size, strides, padding):
    return layers.UpSampling2D(strides)

if UPSAMPLE_MODE=='DECONV':
    upsample=upsample_conv
else:
    upsample=upsample_simple
    
input_img = layers.Input(t_x.shape[1:], name = 'RGB_Input')
pp_in_layer = input_img

if NET_SCALING is not None:
    pp_in_layer = layers.AvgPool2D(NET_SCALING)(pp_in_layer)
    
pp_in_layer = layers.GaussianNoise(GAUSSIAN_NOISE)(pp_in_layer)
pp_in_layer = layers.BatchNormalization()(pp_in_layer)

c1 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (pp_in_layer)
c1 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = layers.MaxPooling2D((2, 2)) (c1)

c2 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = layers.MaxPooling2D((2, 2)) (c2)

c3 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = layers.MaxPooling2D((2, 2)) (c3)

c4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = layers.MaxPooling2D(pool_size=(2, 2)) (c4)


c5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
c5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

u6 = upsample(64, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = layers.concatenate([u6, c4])
c6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u7 = upsample(32, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = layers.concatenate([u7, c3])
c7 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = upsample(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = layers.concatenate([u8, c2])
c8 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = upsample(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = layers.concatenate([u9, c1], axis=3)
c9 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

d = layers.Conv2D(1, (1, 1), activation='sigmoid') (c9)
# d = layers.Cropping2D((EDGE_CROP, EDGE_CROP))(d)
# d = layers.ZeroPadding2D((EDGE_CROP, EDGE_CROP))(d)
if NET_SCALING is not None:
    d = layers.UpSampling2D(NET_SCALING)(d)

seg_model = models.Model(inputs=[input_img], outputs=[d])
seg_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# RGB_Input (InputLayer)          (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 256, 256, 3)  0           RGB_Input[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 256, 256, 3)  0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 3)  12          gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 8)  224         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 8)  584         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 8)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 16) 1168        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 16) 2320        conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 192)  0           up_sampling2d_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 64)   110656      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 96)   0           up_sampling2d_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 32)   27680       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 32)   9248        conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 32) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 48) 0           up_sampling2d_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 16) 6928        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 16) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 24) 0           up_sampling2d_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 8)  1736        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 8)  584         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 1)  9           conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 1)  0           conv2d_19[0][0]
# ==================================================================================================
# Total params: 491,149
# Trainable params: 491,143
# Non-trainable params: 6
# __________________________________________________________________________________________________

# %%
import keras.backend as K
from keras.optimizers import Adam
from keras.losses import binary_crossentropy

from keras.losses import binary_crossentropy
from keras import backend as K

## intersection over union
def IoU(y_true, y_pred, eps=1e-6):
    #print(y_true)
    #if np.max(y_true) == 0.0:
    #    return IoU(1-y_true, 1-y_pred) ## empty image; calc IoU of zeros
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3]) - intersection
    return -K.mean( (intersection + eps) / (union + eps), axis=0)


def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred = K.cast(y_pred, 'float32')
    y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
    intersection = y_true_f * y_pred_f
    score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return score

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

def bce_logdice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

def weighted_bce_loss(y_true, y_pred, weight):
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    loss = weight * (logit_y_pred * (1. - y_true) + 
                     K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
    return K.sum(loss) / K.sum(weight)

def weighted_dice_loss(y_true, y_pred, weight):
    smooth = 1.
    w, m1, m2 = weight, y_true, y_pred
    intersection = (m1 * m2)
    score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
    loss = 1. - K.sum(score)
    return loss

def weighted_bce_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    # if we want to get same size of output, kernel size must be odd
    averaged_mask = K.pool2d(
            y_true, pool_size=(50, 50), strides=(1, 1), padding='same', pool_mode='avg')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight = 5. * K.exp(-5. * K.abs(averaged_mask - 0.5))
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = weighted_bce_loss(y_true, y_pred, weight) + dice_loss(y_true, y_pred)
    return loss

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('seg_model')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only=True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.33,
                                   patience=1, verbose=1, mode='min',
                                   min_delta=0.0001, cooldown=0, min_lr=1e-8)

early = EarlyStopping(monitor="val_loss", mode="min", verbose=2,
                      patience=20) # probably needs to be more patient, but kaggle time is limited

callbacks_list = [checkpoint, early, reduceLROnPlat]

# %%
import numpy as np
import tensorflow as tf
print(np.__version__)
print(keras.__version__)
print(tf.__version__)
# Out:
# 1.17.3
# 2.3.1
# 2.0.0

# %%
train_df['grouped_ship_count'] = train_df['ships'].map(lambda x: (x+1)//2).clip(0, 7)
def sample_ships(in_df, base_rep_val=1500):
    if in_df['ships'].values[0]==0:
        return in_df.sample(base_rep_val//3) # even more strongly undersample no ships
    else:
        return in_df.sample(base_rep_val, replace=(in_df.shape[0]<base_rep_val))
    
balanced_train_df = train_df.groupby('grouped_ship_count').apply(sample_ships)
balanced_train_df['ships'].hist(bins=np.arange(10))

# %%
# %%time
def fit():
    seg_model.compile(optimizer=Adam(1e-3, decay=1e-6), loss=IoU, metrics=['binary_accuracy'])
    
    step_count = min(MAX_TRAIN_STEPS, balanced_train_df.shape[0]//BATCH_SIZE)
    aug_gen = create_aug_gen(make_image_gen(balanced_train_df))
    loss_history = [seg_model.fit_generator(aug_gen,
                                 steps_per_epoch=step_count,
                                 epochs=MAX_TRAIN_EPOCHS,
                                 validation_data=(valid_x, valid_y),
                                 callbacks=callbacks_list,
                                workers=1 # the generator is not very thread safe
                                           )]
    return loss_history

while True:
    loss_history = fit()
    if np.min([mh.history['val_loss'] for mh in loss_history]) < -0.2:
        break
# Out:
# Epoch 1/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.0032 - binary_accuracy: 0.0141 - val_loss: -0.0065 - val_binary_accuracy: 0.0560
#
# Epoch 00001: val_loss improved from inf to -0.00645, saving model to seg_model_weights.best.hdf5
# Epoch 2/99
# 9/9 [==============================] - 20s 2s/step - loss: -0.0043 - binary_accuracy: 0.5034 - val_loss: -0.0082 - val_binary_accuracy: 0.3661
#
# Epoch 00002: val_loss improved from -0.00645 to -0.00821, saving model to seg_model_weights.best.hdf5
# Epoch 3/99
# 9/9 [==============================] - 20s 2s/step - loss: -0.0219 - binary_accuracy: 0.7401 - val_loss: -0.0386 - val_binary_accuracy: 0.9870
#
# Epoch 00003: val_loss improved from -0.00821 to -0.03860, saving model to seg_model_weights.best.hdf5
# Epoch 4/99
# 9/9 [==============================] - 20s 2s/step - loss: -0.0508 - binary_accuracy: 0.8050 - val_loss: -0.0953 - val_binary_accuracy: 0.9250
#
# Epoch 00004: val_loss improved from -0.03860 to -0.09526, saving model to seg_model_weights.best.hdf5
# Epoch 5/99
# 9/9 [==============================] - 19s 2s/step - loss: -0.0554 - binary_accuracy: 0.9483 - val_loss: -0.0851 - val_binary_accuracy: 0.7468
#
# Epoch 00005: val_loss did not improve from -0.09526
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00033000001567415896.
# Epoch 6/99
# 9/9 [==============================] - 20s 2s/step - loss: -0.0773 - binary_accuracy: 0.9123 - val_loss: -0.1533 - val_binary_accuracy: 0.9755
#
# Epoch 00006: val_loss improved from -0.09526 to -0.15330, saving model to seg_model_weights.best.hdf5
# Epoch 7/99
# 9/9 [==============================] - 19s 2s/step - loss: -0.0795 - binary_accuracy: 0.9712 - val_loss: -0.1611 - val_binary_accuracy: 0.9885
#
# Epoch 00007: val_loss improved from -0.15330 to -0.16114, saving model to seg_model_weights.best.hdf5
# Epoch 8/99
# 9/9 [==============================] - 20s 2s/step - loss: -0.0769 - binary_accuracy: 0.9844 - val_loss: -0.1537 - val_binary_accuracy: 0.9731
#
# Epoch 00008: val_loss did not improve from -0.16114
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010890000325161964.
# Epoch 9/99
# 9/9 [==============================] - 20s 2s/step - loss: -0.0890 - binary_accuracy: 0.9724 - val_loss: -0.1630 - val_binary_accuracy: 0.9891
#
# Epoch 00009: val_loss improved from -0.16114 to -0.16301, saving model to seg_model_weights.best.hdf5
# Epoch 10/99
# 9/9 [==============================] - 19s 2s/step - loss: -0.0983 - binary_accuracy: 0.9844 - val_loss: -0.1653 - val_binary_accuracy: 0.9788
#
# Epoch 00010: val_loss improved from -0.16301 to -0.16529, saving model to seg_model_weights.best.hdf5
# Epoch 11/99
# 9/9 [==============================] - 21s 2s/step - loss: -0.1026 - binary_accuracy: 0.9689 - val_loss: -0.1665 - val_binary_accuracy: 0.9773
#
# Epoch 00011: val_loss improved from -0.16529 to -0.16649, saving model to seg_model_weights.best.hdf5
# Epoch 12/99
# 9/9 [==============================] - 20s 2s/step - loss: -0.1159 - binary_accuracy: 0.9766 - val_loss: -0.1641 - val_binary_accuracy: 0.9883
#
# Epoch 00012: val_loss did not improve from -0.16649
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 3.5936999920522795e-05.
# Epoch 13/99
# 9/9 [==============================] - 11s 1s/step - loss: -0.0874 - binary_accuracy: 0.9854 - val_loss: -0.1683 - val_binary_accuracy: 0.9854
#
# Epoch 00013: val_loss improved from -0.16649 to -0.16830, saving model to seg_model_weights.best.hdf5
# Epoch 14/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.0950 - binary_accuracy: 0.9759 - val_loss: -0.1687 - val_binary_accuracy: 0.9741
#
# Epoch 00014: val_loss improved from -0.16830 to -0.16871, saving model to seg_model_weights.best.hdf5
# Epoch 15/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.1117 - binary_accuracy: 0.9729 - val_loss: -0.1729 - val_binary_accuracy: 0.9806
#
# Epoch 00015: val_loss improved from -0.16871 to -0.17289, saving model to seg_model_weights.best.hdf5
# Epoch 16/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.0966 - binary_accuracy: 0.9783 - val_loss: -0.1749 - val_binary_accuracy: 0.9832
#
# Epoch 00016: val_loss improved from -0.17289 to -0.17485, saving model to seg_model_weights.best.hdf5
# Epoch 17/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.0967 - binary_accuracy: 0.9815 - val_loss: -0.1767 - val_binary_accuracy: 0.9837
#
# Epoch 00017: val_loss improved from -0.17485 to -0.17673, saving model to seg_model_weights.best.hdf5
# Epoch 18/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.1018 - binary_accuracy: 0.9812 - val_loss: -0.1785 - val_binary_accuracy: 0.9835
#
# Epoch 00018: val_loss improved from -0.17673 to -0.17851, saving model to seg_model_weights.best.hdf5
# Epoch 19/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.0941 - binary_accuracy: 0.9775 - val_loss: -0.1793 - val_binary_accuracy: 0.9793
#
# Epoch 00019: val_loss improved from -0.17851 to -0.17928, saving model to seg_model_weights.best.hdf5
# Epoch 20/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.0950 - binary_accuracy: 0.9763 - val_loss: -0.1790 - val_binary_accuracy: 0.9769
#
# Epoch 00020: val_loss did not improve from -0.17928
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1.185920958960196e-05.
# Epoch 21/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.1087 - binary_accuracy: 0.9756 - val_loss: -0.1829 - val_binary_accuracy: 0.9819
#
# Epoch 00021: val_loss improved from -0.17928 to -0.18289, saving model to seg_model_weights.best.hdf5
# Epoch 22/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.1124 - binary_accuracy: 0.9805 - val_loss: -0.1854 - val_binary_accuracy: 0.9836
#
# Epoch 00022: val_loss improved from -0.18289 to -0.18538, saving model to seg_model_weights.best.hdf5
# Epoch 23/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1117 - binary_accuracy: 0.9821 - val_loss: -0.1872 - val_binary_accuracy: 0.9835
#
# Epoch 00023: val_loss improved from -0.18538 to -0.18718, saving model to seg_model_weights.best.hdf5
# Epoch 24/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.0885 - binary_accuracy: 0.9810 - val_loss: -0.1886 - val_binary_accuracy: 0.9836
#
# Epoch 00024: val_loss improved from -0.18718 to -0.18856, saving model to seg_model_weights.best.hdf5
# Epoch 25/99
# 9/9 [==============================] - 12s 1s/step - loss: -0.1224 - binary_accuracy: 0.9821 - val_loss: -0.1902 - val_binary_accuracy: 0.9846
#
# Epoch 00025: val_loss improved from -0.18856 to -0.19016, saving model to seg_model_weights.best.hdf5
# Epoch 26/99
# 9/9 [==============================] - 12s 1s/step - loss: -0.1213 - binary_accuracy: 0.9847 - val_loss: -0.1924 - val_binary_accuracy: 0.9848
#
# Epoch 00026: val_loss improved from -0.19016 to -0.19238, saving model to seg_model_weights.best.hdf5
# Epoch 27/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.1046 - binary_accuracy: 0.9827 - val_loss: -0.1941 - val_binary_accuracy: 0.9846
#
# Epoch 00027: val_loss improved from -0.19238 to -0.19414, saving model to seg_model_weights.best.hdf5
# Epoch 28/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.1079 - binary_accuracy: 0.9815 - val_loss: -0.1944 - val_binary_accuracy: 0.9830
#
# Epoch 00028: val_loss improved from -0.19414 to -0.19435, saving model to seg_model_weights.best.hdf5
# Epoch 29/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1069 - binary_accuracy: 0.9795 - val_loss: -0.1946 - val_binary_accuracy: 0.9816
#
# Epoch 00029: val_loss improved from -0.19435 to -0.19460, saving model to seg_model_weights.best.hdf5
# Epoch 30/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1194 - binary_accuracy: 0.9818 - val_loss: -0.1972 - val_binary_accuracy: 0.9850
#
# Epoch 00030: val_loss improved from -0.19460 to -0.19724, saving model to seg_model_weights.best.hdf5
# Epoch 31/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1141 - binary_accuracy: 0.9849 - val_loss: -0.1974 - val_binary_accuracy: 0.9876
#
# Epoch 00031: val_loss improved from -0.19724 to -0.19739, saving model to seg_model_weights.best.hdf5
# Epoch 32/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1145 - binary_accuracy: 0.9871 - val_loss: -0.1985 - val_binary_accuracy: 0.9876
#
# Epoch 00032: val_loss improved from -0.19739 to -0.19854, saving model to seg_model_weights.best.hdf5
# Epoch 33/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1158 - binary_accuracy: 0.9868 - val_loss: -0.2001 - val_binary_accuracy: 0.9872
#
# Epoch 00033: val_loss improved from -0.19854 to -0.20009, saving model to seg_model_weights.best.hdf5
# Epoch 34/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1051 - binary_accuracy: 0.9859 - val_loss: -0.2016 - val_binary_accuracy: 0.9867
#
# Epoch 00034: val_loss improved from -0.20009 to -0.20159, saving model to seg_model_weights.best.hdf5
# Epoch 35/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.0969 - binary_accuracy: 0.9844 - val_loss: -0.2026 - val_binary_accuracy: 0.9859
#
# Epoch 00035: val_loss improved from -0.20159 to -0.20257, saving model to seg_model_weights.best.hdf5
# Epoch 36/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1003 - binary_accuracy: 0.9859 - val_loss: -0.2048 - val_binary_accuracy: 0.9874
#
# Epoch 00036: val_loss improved from -0.20257 to -0.20477, saving model to seg_model_weights.best.hdf5
# Epoch 37/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1030 - binary_accuracy: 0.9885 - val_loss: -0.2053 - val_binary_accuracy: 0.9884
#
# Epoch 00037: val_loss improved from -0.20477 to -0.20527, saving model to seg_model_weights.best.hdf5
# Epoch 38/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1169 - binary_accuracy: 0.9881 - val_loss: -0.2067 - val_binary_accuracy: 0.9887
#
# Epoch 00038: val_loss improved from -0.20527 to -0.20672, saving model to seg_model_weights.best.hdf5
# Epoch 39/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.0988 - binary_accuracy: 0.9881 - val_loss: -0.2077 - val_binary_accuracy: 0.9886
#
# Epoch 00039: val_loss improved from -0.20672 to -0.20768, saving model to seg_model_weights.best.hdf5
# Epoch 40/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1129 - binary_accuracy: 0.9881 - val_loss: -0.2086 - val_binary_accuracy: 0.9883
#
# Epoch 00040: val_loss improved from -0.20768 to -0.20862, saving model to seg_model_weights.best.hdf5
# Epoch 41/99
# 9/9 [==============================] - 11s 1s/step - loss: -0.1089 - binary_accuracy: 0.9860 - val_loss: -0.2083 - val_binary_accuracy: 0.9873
#
# Epoch 00041: val_loss did not improve from -0.20862
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.913539212589967e-06.
# Epoch 42/99
# 9/9 [==============================] - 12s 1s/step - loss: -0.1091 - binary_accuracy: 0.9859 - val_loss: -0.2085 - val_binary_accuracy: 0.9870
#
# Epoch 00042: val_loss did not improve from -0.20862
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.2914679791720119e-06.
# Epoch 43/99
# 9/9 [==============================] - 12s 1s/step - loss: -0.1072 - binary_accuracy: 0.9859 - val_loss: -0.2086 - val_binary_accuracy: 0.9869
#
# Epoch 00043: val_loss did not improve from -0.20862
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 4.2618441511876884e-07.
# Epoch 44/99
# 9/9 [==============================] - 12s 1s/step - loss: -0.1236 - binary_accuracy: 0.9854 - val_loss: -0.2092 - val_binary_accuracy: 0.9870
#
# Epoch 00044: val_loss improved from -0.20862 to -0.20925, saving model to seg_model_weights.best.hdf5
# Epoch 45/99
# 9/9 [==============================] - 12s 1s/step - loss: -0.1211 - binary_accuracy: 0.9872 - val_loss: -0.2099 - val_binary_accuracy: 0.9870
#
# Epoch 00045: val_loss improved from -0.20925 to -0.20987, saving model to seg_model_weights.best.hdf5
# Epoch 46/99
# 9/9 [==============================] - 12s 1s/step - loss: -0.1073 - binary_accuracy: 0.9860 - val_loss: -0.2101 - val_binary_accuracy: 0.9869
#
# Epoch 00046: val_loss improved from -0.20987 to -0.21010, saving model to seg_model_weights.best.hdf5
# Epoch 47/99
# 9/9 [==============================] - 11s 1s/step - loss: -0.1021 - binary_accuracy: 0.9860 - val_loss: -0.2102 - val_binary_accuracy: 0.9869
#
# Epoch 00047: val_loss improved from -0.21010 to -0.21024, saving model to seg_model_weights.best.hdf5
# Epoch 48/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1362 - binary_accuracy: 0.9871 - val_loss: -0.2104 - val_binary_accuracy: 0.9869
#
# Epoch 00048: val_loss improved from -0.21024 to -0.21037, saving model to seg_model_weights.best.hdf5
# Epoch 49/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1400 - binary_accuracy: 0.9862 - val_loss: -0.2103 - val_binary_accuracy: 0.9869
#
# Epoch 00049: val_loss did not improve from -0.21037
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.4064085661402716e-07.
# Epoch 50/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1079 - binary_accuracy: 0.9854 - val_loss: -0.2109 - val_binary_accuracy: 0.9869
#
# Epoch 00050: val_loss improved from -0.21037 to -0.21091, saving model to seg_model_weights.best.hdf5
# Epoch 51/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1288 - binary_accuracy: 0.9867 - val_loss: -0.2112 - val_binary_accuracy: 0.9869
#
# Epoch 00051: val_loss improved from -0.21091 to -0.21118, saving model to seg_model_weights.best.hdf5
# Epoch 52/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.0976 - binary_accuracy: 0.9873 - val_loss: -0.2114 - val_binary_accuracy: 0.9869
#
# Epoch 00052: val_loss improved from -0.21118 to -0.21141, saving model to seg_model_weights.best.hdf5
# Epoch 53/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1076 - binary_accuracy: 0.9853 - val_loss: -0.2116 - val_binary_accuracy: 0.9869
#
# Epoch 00053: val_loss improved from -0.21141 to -0.21164, saving model to seg_model_weights.best.hdf5
# Epoch 54/99
# 9/9 [==============================] - 9s 992ms/step - loss: -0.1090 - binary_accuracy: 0.9866 - val_loss: -0.2120 - val_binary_accuracy: 0.9870
#
# Epoch 00054: val_loss improved from -0.21164 to -0.21196, saving model to seg_model_weights.best.hdf5
# Epoch 55/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1097 - binary_accuracy: 0.9858 - val_loss: -0.2121 - val_binary_accuracy: 0.9870
#
# Epoch 00055: val_loss improved from -0.21196 to -0.21205, saving model to seg_model_weights.best.hdf5
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 4.641148052542121e-08.
# Epoch 56/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1024 - binary_accuracy: 0.9857 - val_loss: -0.2123 - val_binary_accuracy: 0.9870
#
# Epoch 00056: val_loss improved from -0.21205 to -0.21235, saving model to seg_model_weights.best.hdf5
# Epoch 57/99
# 9/9 [==============================] - 9s 984ms/step - loss: -0.1109 - binary_accuracy: 0.9859 - val_loss: -0.2121 - val_binary_accuracy: 0.9870
#
# Epoch 00057: val_loss did not improve from -0.21235
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 1.5315788104430796e-08.
# Epoch 58/99
# 9/9 [==============================] - 9s 993ms/step - loss: -0.1251 - binary_accuracy: 0.9855 - val_loss: -0.2125 - val_binary_accuracy: 0.9870
#
# Epoch 00058: val_loss improved from -0.21235 to -0.21252, saving model to seg_model_weights.best.hdf5
# Epoch 59/99
# 9/9 [==============================] - 9s 994ms/step - loss: -0.1213 - binary_accuracy: 0.9870 - val_loss: -0.2126 - val_binary_accuracy: 0.9870
#
# Epoch 00059: val_loss improved from -0.21252 to -0.21263, saving model to seg_model_weights.best.hdf5
# Epoch 60/99
# 9/9 [==============================] - 9s 981ms/step - loss: -0.1013 - binary_accuracy: 0.9861 - val_loss: -0.2126 - val_binary_accuracy: 0.9870
#
# Epoch 00060: val_loss did not improve from -0.21263
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 1e-08.
# Epoch 61/99
# 9/9 [==============================] - 9s 975ms/step - loss: -0.1336 - binary_accuracy: 0.9869 - val_loss: -0.2128 - val_binary_accuracy: 0.9870
#
# Epoch 00061: val_loss improved from -0.21263 to -0.21277, saving model to seg_model_weights.best.hdf5
# Epoch 62/99
# 9/9 [==============================] - 9s 987ms/step - loss: -0.1101 - binary_accuracy: 0.9852 - val_loss: -0.2129 - val_binary_accuracy: 0.9870
#
# Epoch 00062: val_loss improved from -0.21277 to -0.21290, saving model to seg_model_weights.best.hdf5
# Epoch 63/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1055 - binary_accuracy: 0.9864 - val_loss: -0.2129 - val_binary_accuracy: 0.9870
#
# Epoch 00063: val_loss did not improve from -0.21290
# Epoch 64/99
# 9/9 [==============================] - 9s 990ms/step - loss: -0.1042 - binary_accuracy: 0.9874 - val_loss: -0.2130 - val_binary_accuracy: 0.9870
#
# Epoch 00064: val_loss improved from -0.21290 to -0.21300, saving model to seg_model_weights.best.hdf5
# Epoch 65/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.0969 - binary_accuracy: 0.9859 - val_loss: -0.2131 - val_binary_accuracy: 0.9870
#
# Epoch 00065: val_loss improved from -0.21300 to -0.21308, saving model to seg_model_weights.best.hdf5
# Epoch 66/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1037 - binary_accuracy: 0.9853 - val_loss: -0.2130 - val_binary_accuracy: 0.9870
#
# Epoch 00066: val_loss did not improve from -0.21308
# Epoch 67/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.1239 - binary_accuracy: 0.9857 - val_loss: -0.2131 - val_binary_accuracy: 0.9870
#
# Epoch 00067: val_loss did not improve from -0.21308
# Epoch 68/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.0907 - binary_accuracy: 0.9854 - val_loss: -0.2129 - val_binary_accuracy: 0.9870
#
# Epoch 00068: val_loss did not improve from -0.21308
# Epoch 69/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1242 - binary_accuracy: 0.9869 - val_loss: -0.2131 - val_binary_accuracy: 0.9870
#
# Epoch 00069: val_loss improved from -0.21308 to -0.21314, saving model to seg_model_weights.best.hdf5
# Epoch 70/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1118 - binary_accuracy: 0.9870 - val_loss: -0.2130 - val_binary_accuracy: 0.9870
#
# Epoch 00070: val_loss did not improve from -0.21314
# Epoch 71/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1246 - binary_accuracy: 0.9866 - val_loss: -0.2133 - val_binary_accuracy: 0.9870
#
# Epoch 00071: val_loss improved from -0.21314 to -0.21326, saving model to seg_model_weights.best.hdf5
# Epoch 72/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1111 - binary_accuracy: 0.9862 - val_loss: -0.2131 - val_binary_accuracy: 0.9870
#
# Epoch 00072: val_loss did not improve from -0.21326
# Epoch 73/99
# 9/9 [==============================] - 10s 1s/step - loss: -0.1097 - binary_accuracy: 0.9856 - val_loss: -0.2132 - val_binary_accuracy: 0.9870
#
# Epoch 00073: val_loss did not improve from -0.21326
# Epoch 74/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1019 - binary_accuracy: 0.9864 - val_loss: -0.2132 - val_binary_accuracy: 0.9870
#
# Epoch 00074: val_loss did not improve from -0.21326
# Epoch 75/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1070 - binary_accuracy: 0.9859 - val_loss: -0.2131 - val_binary_accuracy: 0.9870
#
# Epoch 00075: val_loss did not improve from -0.21326
# Epoch 76/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.0942 - binary_accuracy: 0.9853 - val_loss: -0.2134 - val_binary_accuracy: 0.9870
#
# Epoch 00076: val_loss improved from -0.21326 to -0.21336, saving model to seg_model_weights.best.hdf5
# Epoch 77/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1161 - binary_accuracy: 0.9859 - val_loss: -0.2128 - val_binary_accuracy: 0.9870
#
# Epoch 00077: val_loss did not improve from -0.21336
# Epoch 78/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1157 - binary_accuracy: 0.9865 - val_loss: -0.2132 - val_binary_accuracy: 0.9870
#
# Epoch 00078: val_loss did not improve from -0.21336
# Epoch 79/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1182 - binary_accuracy: 0.9863 - val_loss: -0.2131 - val_binary_accuracy: 0.9870
#
# Epoch 00079: val_loss did not improve from -0.21336
# Epoch 80/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1376 - binary_accuracy: 0.9867 - val_loss: -0.2131 - val_binary_accuracy: 0.9871
#
# Epoch 00080: val_loss did not improve from -0.21336
# Epoch 81/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1254 - binary_accuracy: 0.9864 - val_loss: -0.2133 - val_binary_accuracy: 0.9871
#
# Epoch 00081: val_loss did not improve from -0.21336
# Epoch 82/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1012 - binary_accuracy: 0.9854 - val_loss: -0.2133 - val_binary_accuracy: 0.9871
#
# Epoch 00082: val_loss did not improve from -0.21336
# Epoch 83/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1209 - binary_accuracy: 0.9860 - val_loss: -0.2131 - val_binary_accuracy: 0.9870
#
# Epoch 00083: val_loss did not improve from -0.21336
# Epoch 84/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1160 - binary_accuracy: 0.9866 - val_loss: -0.2134 - val_binary_accuracy: 0.9871
#
# Epoch 00084: val_loss did not improve from -0.21336
# Epoch 85/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1226 - binary_accuracy: 0.9867 - val_loss: -0.2133 - val_binary_accuracy: 0.9871
#
# Epoch 00085: val_loss did not improve from -0.21336
# Epoch 86/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1145 - binary_accuracy: 0.9882 - val_loss: -0.2136 - val_binary_accuracy: 0.9871
#
# Epoch 00086: val_loss improved from -0.21336 to -0.21363, saving model to seg_model_weights.best.hdf5
# Epoch 87/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1206 - binary_accuracy: 0.9857 - val_loss: -0.2135 - val_binary_accuracy: 0.9871
#
# Epoch 00087: val_loss did not improve from -0.21363
# Epoch 88/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1047 - binary_accuracy: 0.9866 - val_loss: -0.2136 - val_binary_accuracy: 0.9871
#
# Epoch 00088: val_loss did not improve from -0.21363
# Epoch 89/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1175 - binary_accuracy: 0.9857 - val_loss: -0.2138 - val_binary_accuracy: 0.9871
#
# Epoch 00089: val_loss improved from -0.21363 to -0.21376, saving model to seg_model_weights.best.hdf5
# Epoch 90/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1291 - binary_accuracy: 0.9868 - val_loss: -0.2137 - val_binary_accuracy: 0.9871
#
# Epoch 00090: val_loss did not improve from -0.21376
# Epoch 91/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.0980 - binary_accuracy: 0.9863 - val_loss: -0.2137 - val_binary_accuracy: 0.9871
#
# Epoch 00091: val_loss did not improve from -0.21376
# Epoch 92/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.0997 - binary_accuracy: 0.9865 - val_loss: -0.2135 - val_binary_accuracy: 0.9871
#
# Epoch 00092: val_loss did not improve from -0.21376
# Epoch 93/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1187 - binary_accuracy: 0.9854 - val_loss: -0.2137 - val_binary_accuracy: 0.9871
#
# Epoch 00093: val_loss did not improve from -0.21376
# Epoch 94/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1207 - binary_accuracy: 0.9869 - val_loss: -0.2135 - val_binary_accuracy: 0.9871
#
# Epoch 00094: val_loss did not improve from -0.21376
# Epoch 95/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1190 - binary_accuracy: 0.9859 - val_loss: -0.2132 - val_binary_accuracy: 0.9871
#
# Epoch 00095: val_loss did not improve from -0.21376
# Epoch 96/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1200 - binary_accuracy: 0.9864 - val_loss: -0.2132 - val_binary_accuracy: 0.9871
#
# Epoch 00096: val_loss did not improve from -0.21376
# Epoch 97/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1069 - binary_accuracy: 0.9857 - val_loss: -0.2134 - val_binary_accuracy: 0.9871
#
# Epoch 00097: val_loss did not improve from -0.21376
# Epoch 98/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.0932 - binary_accuracy: 0.9857 - val_loss: -0.2134 - val_binary_accuracy: 0.9871
#
# Epoch 00098: val_loss did not improve from -0.21376
# Epoch 99/99
# 9/9 [==============================] - 9s 1s/step - loss: -0.1036 - binary_accuracy: 0.9850 - val_loss: -0.2135 - val_binary_accuracy: 0.9871
#
# Epoch 00099: val_loss did not improve from -0.21376
# CPU times: user 17min 33s, sys: 1min 26s, total: 19min
# Wall time: 17min 58s

# %%
def show_loss(loss_history):
    epochs = np.concatenate([mh.epoch for mh in loss_history])
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(22, 10))
    
    _ = ax1.plot(epochs, np.concatenate([mh.history['loss'] for mh in loss_history]), 'b-',
                 epochs, np.concatenate([mh.history['val_loss'] for mh in loss_history]), 'r-')
    ax1.legend(['Training', 'Validation'])
    ax1.set_title('Loss')
    
    _ = ax2.plot(epochs, np.concatenate([mh.history['binary_accuracy'] for mh in loss_history]), 'b-',
                 epochs, np.concatenate([mh.history['val_binary_accuracy'] for mh in loss_history]), 'r-')
    ax2.legend(['Training', 'Validation'])
    ax2.set_title('Binary Accuracy (%)')

show_loss(loss_history)

# %%
weight_path
# Out:
# 'seg_model_weights.best.hdf5'

# %%
seg_model.load_weights(weight_path)
seg_model.save(path + 'models/seg_model.h5')

# %%
pred_y = seg_model.predict(valid_x)
print(pred_y.shape, pred_y.min(axis=0).max(), pred_y.max(axis=0).min(), pred_y.mean())
# Out:
# (900, 256, 256, 1) 0.0 1.8149614e-05 0.0130425235

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 6))
ax.hist(pred_y.ravel(), np.linspace(0, 1, 20))
ax.set_xlim(0, 1)
ax.set_yscale('log', nonposy='clip')

# %% [markdown]
# # Prepare Full Resolution Model
# Here we account for the scaling so everything can happen in the model itself

# %%
if IMG_SCALING is not None:
    fullres_model = models.Sequential()
    fullres_model.add(layers.AvgPool2D(IMG_SCALING, input_shape = (None, None, 3)))
    fullres_model.add(seg_model)
    fullres_model.add(layers.UpSampling2D(IMG_SCALING))
else:
    fullres_model = seg_model
fullres_model.save('fullres_model.h5')

# %% [markdown]
# # Visualize predictions

# %%
def raw_prediction(img, path=test_image_dir):
    c_img = imread(os.path.join(path, c_img_name))
    c_img = np.expand_dims(c_img, 0)/255.0
    cur_seg = fullres_model.predict(c_img)[0]
    return cur_seg, c_img[0]

def smooth(cur_seg):
    return binary_opening(cur_seg>0.99, np.expand_dims(disk(2), -1))

def predict(img, path=test_image_dir):
    cur_seg, c_img = raw_prediction(img, path=path)
    return smooth(cur_seg), c_img

## Get a sample of each group of ship count
samples = valid_df.groupby('ships').apply(lambda x: x.sample(1))
fig, m_axs = plt.subplots(samples.shape[0], 4, figsize = (15, samples.shape[0]*4))
[c_ax.axis('off') for c_ax in m_axs.flatten()]

for (ax1, ax2, ax3, ax4), c_img_name in zip(m_axs, samples.ImageId.values):
    first_seg, first_img = raw_prediction(c_img_name, train_image_dir)
    ax1.imshow(first_img)
    ax1.set_title('Image: ' + c_img_name)
    ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
    ax2.set_title('Model Prediction')
    reencoded = masks_as_color(multi_rle_encode(smooth(first_seg)[:, :, 0]))
    ax3.imshow(reencoded)
    ax3.set_title('Prediction Masks')
    ground_truth = masks_as_color(masks.query('ImageId=="{}"'.format(c_img_name))['EncodedPixels'])
    ax4.imshow(ground_truth)
    ax4.set_title('Ground Truth')
    
fig.savefig('validation.png')

# %% [markdown]
# # visualization with {}

# %%
def raw_prediction(img, path=test_image_dir):
    c_img = imread(os.path.join(path, c_img_name))
    c_img = np.expand_dims(c_img, 0)/255.0
    cur_seg = fullres_model.predict(c_img)[0]
    return cur_seg, c_img[0]

def smooth(cur_seg):
    return binary_opening(cur_seg>0.99, np.expand_dims(disk(2), -1))

def predict(img, path=test_image_dir):
    cur_seg, c_img = raw_prediction(img, path=path)
    return smooth(cur_seg), c_img

## Get a sample of each group of ship count
samples = valid_df.groupby('ships').apply(lambda x: x.sample(1))
fig, m_axs = plt.subplots(samples.shape[0], 4, figsize = (15, samples.shape[0]*4))
[c_ax.axis('off') for c_ax in m_axs.flatten()]

for (ax1, ax2, ax3, ax4), c_img_name in zip(m_axs, samples.ImageId.values):
    first_seg, first_img = raw_prediction(c_img_name, train_image_dir)
    ax1.imshow(first_img)
    ax1.set_title('Image: ' + c_img_name)
    ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
    ax2.set_title('Model Prediction')
    reencoded = masks_as_color(multi_rle_encode(smooth(first_seg)[:, :, 0]))
    ax3.imshow(reencoded)
    ax3.set_title('Prediction Masks')
    ground_truth = masks_as_color(masks.query('ImageId=="{}"'.format(c_img_name))['EncodedPixels'])
    ax4.imshow(ground_truth)
    ax4.set_title('Ground Truth')
    
fig.savefig('validation.png')

# %% [markdown]
# # Submission

# %%
test_paths = np.array(os.listdir(test_image_dir))
print(len(test_paths), 'test images found')
# Out:
# 15606 test images found

# %%
from tqdm import tqdm_notebook

def pred_encode(img, **kwargs):
    cur_seg, _ = predict(img)
    cur_rles = multi_rle_encode(cur_seg, **kwargs)
    return [[img, rle] for rle in cur_rles if rle is not None]

out_pred_rows = []
for c_img_name in tqdm_notebook(test_paths[:30000]): ## only a subset as it takes too long to run
    out_pred_rows += pred_encode(c_img_name, min_max_threshold=1.0)
# Out:
# /home/jake/venv/lib/python3.7/site-packages/ipykernel_launcher.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   if __name__ == '__main__':
# HBox(children=(IntProgress(value=0, max=15606), HTML(value='')))

# %%
sub = pd.DataFrame(out_pred_rows)
sub.columns = ['ImageId', 'EncodedPixels']
sub = sub[sub.EncodedPixels.notnull()]
sub.head()

# %%
## let's see what we got
TOP_PREDICTIONS=5
fig, m_axs = plt.subplots(TOP_PREDICTIONS, 2, figsize = (9, TOP_PREDICTIONS*5))
[c_ax.axis('off') for c_ax in m_axs.flatten()]

for (ax1, ax2), c_img_name in zip(m_axs, sub.ImageId.unique()[:TOP_PREDICTIONS]):
    c_img = imread(os.path.join(test_image_dir, c_img_name))
    c_img = np.expand_dims(c_img, 0)/255.0
    ax1.imshow(c_img[0])
    ax1.set_title('Image: ' + c_img_name)
    ax2.imshow(masks_as_color(sub.query('ImageId=="{}"'.format(c_img_name))['EncodedPixels']))
    ax2.set_title('Prediction')

# %%
sub1 = pd.read_csv('../input/sample_submission_v2.csv')
sub1 = pd.DataFrame(np.setdiff1d(sub1['ImageId'].unique(), sub['ImageId'].unique(), assume_unique=True), columns=['ImageId'])
sub1['EncodedPixels'] = None
print(len(sub1), len(sub))

sub = pd.concat([sub, sub1])
print(len(sub))
sub.to_csv('submission.csv', index=False)
sub.head()

# %% [markdown]
# # ship no ship

# %%
have_ship= pd.read_csv("Have_ship_or_not.csv")

# %%
test_names = have_ship.loc[have_ship['Have_ship'] > 0.5, ['ImageId']]['ImageId'].values.tolist()
test_names_nothing = have_ship.loc[have_ship['Have_ship'] <= 0.5, ['ImageId']]['ImageId'].values.tolist()
len(test_names), len(test_names_nothing)

# %%
ship_list_dict = []
for name in test_names_nothing:
    ship_list_dict.append({'ImageId':name,'EncodedPixels':None})

# %%
ship_list_dict = []
for name in test_names_nothing:
    ship_list_dict.append({'ImageId':name,'EncodedPixels':None})

# %%
test_paths = np.array(os.listdir(test_image_dir))
print(len(test_paths), 'test images found')

# %%
# %%time
from tqdm import tqdm_notebook
from skimage.morphology import binary_opening, disk
for c_img_name in tqdm_notebook(test_paths):
    if c_img_name in test_names:
        c_path = os.path.join(test_image_dir, c_img_name)
        c_img = imread(c_path)
        c_img = np.expand_dims(c_img, 0)/255.0
        cur_seg = fullres_model.predict(c_img)[0]
        cur_seg = binary_opening(cur_seg>0.5, np.expand_dims(disk(2), -1))
        cur_rles = multi_rle_encode(cur_seg)
        if len(cur_rles)>0:
            for c_rle in cur_rles:
                ship_list_dict += [{'ImageId': c_img_name, 'EncodedPixels': c_rle}]
        else:
            ship_list_dict += [{'ImageId': c_img_name, 'EncodedPixels': 'None'}]
    gc.collect()

# %%
submission_df = pd.DataFrame(ship_list_dict)[['ImageId', 'EncodedPixels']]
submission_df.to_csv('submission_noship.csv', index=False)
submission_df.sample(3)

# %%
submission_df.loc[submission_df['EncodedPixels'] != None]
